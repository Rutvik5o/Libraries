# %%
import pandas as pd

# %%
df = pd.read_csv("datatwo.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Vikciy Koushal                      xxyz  2023           Action
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 2              JK shah                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2              JK shah                    Dangal  2016        Biography
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Vikciy Koushal                      xxyz  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year",ascending=False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Vikciy Koushal                      xxyz  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2              JK shah                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2=df.sort_values(["Year","IMDb"]).copy() #for tie

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2              JK shah                    Dangal  2016        Biography
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Vikciy Koushal                      xxyz  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#for fresh indexing

# %%
df2=df2.reset_index()
df2
# Out:
#     level_0  index               Actor                      Film  Year  \
# 0         0      2             JK shah                    Dangal  2016
# 1         1      1         Jitu Bhaiya           Tiger Zinda Hai  2017
# 2         2     10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 3         3      4       Ranveer Singh                 Padmaavat  2018
# 4         4      6       Rajkummar Rao                     Stree  2018
# 5         5      5  Ayushmann Khurrana                 Andhadhun  2018
# 6         6      7      Hrithik Roshan                       War  2019
# 7         7      8        Akshay Kumar                Good Newwz  2019
# 8         8     11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 9         9      3       Ranbir Kapoor                Brahmastra  2022
# 10       10      9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 11       11      0      Vikciy Koushal                      xxyz  2023
#
# ...

# %%
#giving old index

# %%
df2

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Vikciy Koushal                      xxyz  2023           Action
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 2              JK shah                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2=df.sort_values(["Year","IMDb"]).copy()

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2              JK shah                    Dangal  2016        Biography
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Vikciy Koushal                      xxyz  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       2             JK shah                    Dangal  2016
# 1       1         Jitu Bhaiya           Tiger Zinda Hai  2017
# 2      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 3       4       Ranveer Singh                 Padmaavat  2018
# 4       6       Rajkummar Rao                     Stree  2018
# 5       5  Ayushmann Khurrana                 Andhadhun  2018
# 6       7      Hrithik Roshan                       War  2019
# 7       8        Akshay Kumar                Good Newwz  2019
# 8      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 9       3       Ranbir Kapoor                Brahmastra  2022
# 10      9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 11      0      Vikciy Koushal                      xxyz  2023
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0         Biography                  2024   8.4
# 1            Action                   565   6.0
# ...

# %%
df2.reset_index(drop=True,inplace=True) #drop =true-> does'nt make new collumn of old indexes

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0              JK shah                    Dangal  2016        Biography
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Vikciy Koushal                      xxyz  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#inplace = Ture-> yahi vala dataset ko update kardo

# %%
#df2["Rank"] = df2["IMDb"].rank()
df2["Rank"] = df2["IMDb"].rank(ascending=False,method="dense")

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0              JK shah                    Dangal  2016        Biography
# 1          Jitu Bhaiya           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Vikciy Koushal                      xxyz  2023           Action
#
# ...

# %%
#method=dense for sharing same rank

# %%
#can be also reorderr
#df.columns=["Name","Age","City",..all columns name

# %%
#another way

# %%
cols=["Film"] + [col for col in df.columns if col != "Film"]
df2=df2[cols]
df2
# Out:
#                         Film               Actor  Year  Year            Genre  \
# 0                     Dangal             JK shah  2016  2016        Biography
# 1            Tiger Zinda Hai         Jitu Bhaiya  2017  2017           Action
# 2      Badrinath Ki Dulhania        Varun Dhawan  2017  2017  Romantic Comedy
# 3                  Padmaavat       Ranveer Singh  2018  2018       Historical
# 4                      Stree       Rajkummar Rao  2018  2018    Horror Comedy
# 5                  Andhadhun  Ayushmann Khurrana  2018  2018         Thriller
# 6                        War      Hrithik Roshan  2019  2019           Action
# 7                 Good Newwz        Akshay Kumar  2019  2019           Comedy
# 8   Uri: The Surgical Strike       Vicky Kaushal  2019  2019           Action
# 9                 Brahmastra       Ranbir Kapoor  2022  2022          Fantasy
# 10         Bhool Bhulaiyaa 2       Kartik Aaryan  2022  2022    Horror Comedy
# ...
