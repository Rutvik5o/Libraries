# %% [markdown]
# ## Histrogram Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_excel("rich.xlsx")
data
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore Region Membership  \
# 0             1   63  Female         20268             17   West       Gold
# 1             2   20  Female        110986             43   West     Silver
# 2             3   46  Female        118842             58   West     Silver
# 3             4   52  Female         53223             19  North     Bronze
# 4             5   56    Male         40265             54   East     Bronze
# ..          ...  ...     ...           ...            ...    ...        ...
# 295         296   18    Male         37440             52   East     Bronze
# 296         297   53  Female         86296             25   East     Bronze
# 297         298   37  Female         33312             13   West     Silver
# 298         299   48  Female         78958             80   East       Gold
# 299         300   25  Female        117407             84   East     Silver
#
#      PurchaseFrequency  TotalPurchases  Satisfaction
# ...

# %%
sns.displot(data['SpendingScore'])
plt.show()

# %%
sns.histplot(data["SpendingScore"])
plt.show()

# %%
d2 =sns.load_dataset("penguins")
d2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(d2["flipper_length_mm"])

# %%
#value frequency are not same in x axecs

# %%
sns.displot(d2["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240],
           kde=True,rug=True,color="orange") #fixed range

#kde -> Kernal Density Estimator
#rug-> show density accoridng x axes also(niche lines aa chuki he x axes he)
#log_scale-> if you bins then it doesn't work
